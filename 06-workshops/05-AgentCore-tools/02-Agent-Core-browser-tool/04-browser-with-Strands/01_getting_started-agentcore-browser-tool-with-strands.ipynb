# %% [markdown]
# # 🌐 Strands + AgentCore Browser 통합
#
# ## 개요
#
# 이 튜토리얼에서는 지능형 웹 자동화와 재무 분석을 위해 Strands Agent와 Amazon Bedrock AgentCore Browser tool을 함께 사용하는 방법을 알아봅니다. 공식 `strands_tools.browser.AgentCoreBrowser` 통합을 사용해 웹 사이트를 탐색하고 재무 데이터를 추출하며 AI 기반 인사이트를 제공하는 Strands Agent를 생성하는 과정을 살펴봅니다.
#
# ### 튜토리얼 세부 정보
#
# | 항목                | 세부 정보                                                                        |
# |:--------------------|:---------------------------------------------------------------------------------|
# | 튜토리얼 유형       | 대화형                                                                           |
# | Agent 유형          | 단일                                                                             |
# | Agentic Framework   | Strands                                                                          |
# | LLM 모델            | Claude 3 Haiku                                                                   |
# | 튜토리얼 구성 요소  | 브라우저 자동화, 재무 분석, 오류 복구                                            |
# | 튜토리얼 분야       | 금융 기술                                                                        |
# | 예제 난이도         | 중급                                                                             |
# | 사용 SDK            | Amazon BedrockAgentCore Python SDK, Strands Agents, Strands Agent Tools         |
#
# ### 튜토리얼 아키텍처
#
# 이 튜토리얼에서는 지능형 금융 웹 사이트 분석을 위해 Strands Agent와 Browser tool을 함께 사용하는 방법을 설명합니다. 구현에는 Strands와 AWS Bedrock AgentCore를 원활하게 통합하는 공식 `strands_tools.browser.AgentCoreBrowser`를 사용합니다.
#
# 예제에서는 Strands Agent에 자연어 지시를 보내 MarketWatch와 같은 웹 사이트에서 재무 분석 작업을 수행하고, 주식 데이터와 시장 지표를 추출해 AI 기반 인사이트를 제공합니다.
#
# ### 튜토리얼 주요 기능
#
# * Strands Agent와 Browser tool을 headless 방식으로 사용
# * strands_tools.browser를 사용한 AgentCoreBrowser 통합
# * 맥락 인식 AI 응답을 활용한 지능형 금융 웹 사이트 분석
# * Fallback 전략을 활용한 오류 처리 및 응답 파싱
# * 안정적인 Agent 구현을 위한 구조화된 invoke pattern
# * 빠르고 효율적인 분석을 위한 Claude Haiku 모델
#
# ## 사전 요구 사항
#
# 이 튜토리얼을 실행하려면 다음이 필요합니다.
# * Python 3.10+
# * 구성된 AWS 자격 증명
# * Amazon Bedrock AgentCore SDK
# * Strands Agent 및 strands-agents-tools package
# * Amazon Bedrock의 Claude 3 Haiku 모델에 대한 액세스 권한
#
# **구현**: 공식 `strands_tools.browser.AgentCoreBrowser`를 사용해 지능형 재무 분석과 브라우저 자동화를 원활하게 통합합니다.
#
# ## 🎯 주요 기능
# - `strands_tools.browser`를 사용한 **AgentCoreBrowser 통합**
# - 맥락 인식 AI 응답을 활용한 **MarketWatch 재무 분석**
# - 구현을 위한 **구조화된 invoke pattern**
# - 빠르고 효율적인 분석을 위한 **Claude Haiku 모델**
#
# ## 🏗️ 아키텍처
#
# ```mermaid
# graph TD
#     A[👤 사용자 요청] --> B[📋 Invoke Function]
#     B --> C[🤖 Strands Agent]
#     C --> D[🔧 AgentCoreBrowser Tool]
#     D --> E[🌐 AWS Bedrock AgentCore]
#     E --> F[🎭 Browser Automation]
#     F --> G[📊 MarketWatch.com]
#     G --> H[📈 주식 데이터 추출]
#     H --> I[🧠 Claude 분석]
#     I --> J[📋 재무 인사이트]
#
#     style A fill:#1a1a2e
#     style C fill:#16213e
#     style D fill:#0f3460
#     style E fill:#e94560
#     style I fill:#f39c12
# ```

# %% [markdown]
# ## 📦 1단계: Dependency 설치

# %%
# AgentCoreBrowser용 strands-agents-tools와 필수 package 설치
# !pip install --force-reinstall -U -r requirements.txt 

print("✅ Dependencies installed successfully!")

# %% [markdown]
# ## 📚 2단계: 라이브러리 import

# %%
from strands import Agent
from strands_tools.browser import AgentCoreBrowser
import time

print("✅ Libraries imported successfully!")

# %% [markdown]
# ## 🤖 3단계: 최적화된 설정으로 Agent 생성

# %%
def create_agent():
    """AgentCoreBrowser를 사용하는 Strands 에이전트를 생성하고 구성합니다."""
    # 공식 AgentCoreBrowser tool 초기화
    agent_core_browser = AgentCoreBrowser(region="us-west-2")

    # Claude Haiku 모델과 최적화된 설정으로 Agent 생성
    agent = Agent(
        tools=[agent_core_browser.browser],
        model="global.anthropic.claude-haiku-4-5-20251001-v1:0",
        system_prompt="""You are an intelligent financial analyst that specializes in analyzing stock and financial websites. When asked to analyze a financial website:

1. Use the browser tool to visit and interact with the website EFFICIENTLY
2. Focus on extracting key financial information QUICKLY:

**For Financial/Stock Websites (MarketWatch, Bloomberg, etc.):**
- Current stock prices and market data
- Price movements and trends (daily, weekly, monthly changes)
- Key financial metrics and ratios (P/E, Market Cap, etc.)
- Trading volume and market activity
- Recent news and market sentiment
- Analyst recommendations and price targets
- Company fundamentals and performance indicators

IMPORTANT: Work efficiently and complete your analysis within 2-3 browser interactions. Always provide specific, actionable financial insights with actual numbers and data points. Be concise but comprehensive in your analysis, focusing on the most important financial metrics for investors.""",
    )
    return agent


# Agent를 전역으로 초기화
strands_agent = create_agent()

print("✅ Strands agent created with AgentCoreBrowser integration!")

# %% [markdown]
# ## 🔧 4단계: Invoke function 생성

# %%
def invoke(payload):
    """에이전트 상호 작용을 위한 구조화된 호출 함수입니다."""
    user_message = payload.get("prompt", "")

    try:
        print("🚀 Starting analysis...")
        start_time = time.time()

        response = strands_agent(user_message)

        elapsed_time = time.time() - start_time
        print(f"✅ Analysis completed in {elapsed_time:.2f} seconds")

        return response.message["content"][0]["text"] if response.message.get("content") else str(response)

    except Exception as e:
        print(f"❌ Error during analysis: {str(e)}")
        return f"Error occurred: {str(e)}"


print("✅ Invoke function created!")

# 📝 참고: 응답이 느려 timeout이 발생하는 웹 사이트에 접근할 때는 작업이
# 멈추지 않도록 코드에 timeout 처리를 구현해야 할 수 있습니다.

# %% [markdown]
# ## 📊 5단계: MarketWatch 재무 분석 테스트

# %%
# MarketWatch Tesla 페이지로 테스트
financial_test = {
    "prompt": "Please analyze the Tesla stock page at https://www.marketwatch.com/investing/stock/tsla and provide key financial insights"
}

print("📊 Testing MarketWatch Financial Analysis")
print("=" * 50)

result = invoke(financial_test)
print(result)

print("\n✅ MarketWatch analysis test completed!")

# %% [markdown]
# ## 🎯 6단계: 대화형 분석 function

# %%
def analyze_website(url, question=None):
    """대화형 웹 사이트 분석을 위한 편의 함수입니다."""
    if question:
        prompt = f"Visit {url} and answer this question: {question}"
    else:
        prompt = f"Please analyze the website at {url} and provide comprehensive financial insights"

    payload = {"prompt": prompt}
    return invoke(payload)


# 사용 예제
print("🎯 Interactive Analysis Function Ready!")
print("\nExample usage:")
print(
    'analyze_website("https://www.marketwatch.com/investing/stock/aapl", "What is Apple\'s current stock performance?")'
)
print("\n✅ Interactive analysis function ready!")

# %% [markdown]
# ## 🔄 7단계: Main function

# %%
if __name__ == "__main__":
    # MarketWatch 사용 예제
    print("🎯 Production Example - Tesla Stock Analysis on MarketWatch:")
    print("=" * 60)

    response = invoke(
        {
            "prompt": "Analyze the Tesla stock at https://www.marketwatch.com/investing/stock/tsla and provide detailed financial insights"
        }
    )

    print(response)

    print("\n✅ All tests completed successfully!")
    print("\n🚀 Ready for production use with the invoke() function pattern!")
    print("\n📝 Usage Examples:")
    print('invoke({"prompt": "Analyze Tesla stock at https://www.marketwatch.com/investing/stock/tsla"})')
    print('invoke({"prompt": "Get Apple stock data from https://www.marketwatch.com/investing/stock/aapl"})')
    print(
        'analyze_website("https://www.marketwatch.com/investing/stock/nvda", "What is NVIDIA\'s market performance?")'
    )

# %% [markdown]
# ## 🎭 내부에서는 어떤 일이 일어났을까요?
#
# 이 Notebook을 실행하면 Strands Agent가 Claude Haiku 모델로 초기화되고 Amazon Bedrock AgentCore Browser에 연결됩니다. 재무 분석 요청을 받으면 Agent는 MarketWatch.com을 탐색해 가격, 시가 총액, P/E 비율, 거래량 등의 실시간 주식 데이터를 추출한 다음, Claude AI로 정보를 처리해 종합적인 재무 인사이트를 생성합니다.
#
# 성능 추적 기능은 실행 속도(일반적으로 14~16초)를 측정하며, 오류 처리 기능은 네트워크 문제나 웹 사이트 차단을 안정적으로 관리합니다. 전체 프로세스는 `invoke()` function pattern으로 조정됩니다. 이 pattern은 간결한 interface를 제공하면서 내부의 복잡한 브라우저 자동화와 AI 처리를 관리합니다.
#
# 결과적으로 단순한 function 호출처럼 보이지만, 실제로는 여러 AWS 서비스, AI 모델 및 web scraping을 조정해 신뢰할 수 있는 재무 분석을 제공합니다.
#
# ### 📝 **사용 예제:**
# ```python
# # 직접 invoke pattern 사용(production)
# result = invoke({"prompt": "Analyze Tesla stock at https://www.marketwatch.com/investing/stock/tsla"})
#
# # 대화형 helper function
# result = analyze_website("https://www.marketwatch.com/investing/stock/aapl", "What is Apple's current valuation?")
# ```
