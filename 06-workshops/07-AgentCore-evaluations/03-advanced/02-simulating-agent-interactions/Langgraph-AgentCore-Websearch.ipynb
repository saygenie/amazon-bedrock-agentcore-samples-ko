# %% [markdown]
# # Actor Simulator를 활용한 AgentCore 온라인 평가 - Web Search Agent
#
# **파이프라인:** AgentCore Evaluations 온라인 평가 설정 → DatasetGenerator → ActorSimulator → 에이전트 호출 → CloudWatch를 통한 AgentCore 평가
#
# 이 노트북에서는 다음 작업을 수행합니다.
# 1. `eval_config.py`에서 구성을 불러옵니다.
# 2. 웹 검색 품질을 위한 사용자 지정 LLM-as-a-Judge evaluator를 생성합니다.
# 3. 기본 제공 metric과 사용자 지정 metric으로 AgentCore 온라인 평가를 설정합니다.
# 4. DatasetGenerator를 사용해 웹 검색 시나리오용 테스트 사례를 생성합니다.
# 5. actor simulator를 실행해 멀티턴 대화로 에이전트를 호출합니다.
# 6. AgentCore가 CloudWatch를 통해 trace를 자동으로 캡처하고 평가합니다.

# %% [markdown]
# ## 1. 가져오기 및 구성

# %%
import boto3
import json
import os
import uuid
from strands_evals import ActorSimulator, Case
from strands_evals.generators import DatasetGenerator
from lg_eval_config import *

os.environ["AWS_DEFAULT_REGION"] = AWS_REGION
print("Configuration loaded from eval_config.py")
# Out:
# Configuration loaded from eval_config.py

# %% [markdown]
# ## 2. 사용자 지정 Evaluator 생성(LLM-as-a-Judge)
#
# 다음 항목을 포함한 웹 검색 품질을 평가하도록 사용자 지정 evaluator를 생성합니다.
# - 검색 결과의 관련성
# - 정보 종합 품질
# - 출처 표시
# - 정보의 최신성

# %%
evaluation_client = boto3.client(
    "agentcore-evaluation-controlplane",
    region_name=AWS_REGION,
)

# 사용자 지정 evaluator를 생성합니다.
try:
    custom_evaluator_response = evaluation_client.create_evaluator(
        evaluatorName=CUSTOM_EVALUATOR_NAME,
        level="TRACE",
        evaluatorConfig=CUSTOM_EVALUATOR_CONFIG,
    )
    print(f"✓ Created custom evaluator: {CUSTOM_EVALUATOR_NAME}")
    print(json.dumps(custom_evaluator_response, indent=2, default=str))
    custom_evaluator_id = custom_evaluator_response["evaluatorId"]
except Exception as e:
    if "ResourceConflictException" in str(e) or "already exists" in str(e):
        print(f"⚠ Custom evaluator '{CUSTOM_EVALUATOR_NAME}' already exists, using existing one")
        # evaluator 목록에서 기존 ID를 가져옵니다.
        list_response = evaluation_client.list_evaluators()
        for evaluator in list_response.get("evaluators", []):
            if evaluator["evaluatorName"] == CUSTOM_EVALUATOR_NAME:
                custom_evaluator_id = evaluator["evaluatorId"]
                print(f"✓ Found existing evaluator ID: {custom_evaluator_id}")
                break
    else:
        print(f"✗ Error creating custom evaluator: {e}")
        raise

create_config_response = evaluation_client.create_online_evaluation_config(
    onlineEvaluationConfigName="custom_web_search_quality_evaluator",
    description="Integration test config",
    rule={"samplingConfig": {"samplingPercentage": 100.0}},
    dataSourceConfig={
        "cloudWatchLogs": {
            "logGroupNames": [LOG_GROUP_NAME],
            "serviceNames": [SERVICE_NAME],
        }
    },
    evaluators=[{"evaluatorId": custom_evaluator_id}],
    evaluationExecutionRoleArn=EVALUATION_ROLE_ARN,
    enableOnCreate=True,
)

# %% [markdown]
# ## 3. AgentCore 온라인 평가 설정
#
# 기본 제공 evaluator와 사용자 지정 evaluator를 모두 사용하도록 온라인 평가를 구성합니다.

# %%
# 기본 제공 evaluator와 사용자 지정 evaluator를 결합합니다.
all_evaluators = [{"evaluatorId": evaluator_id} for evaluator_id in EVALUATORS]

print(f"Total evaluators: {len(all_evaluators)} (13 builtin + 1 custom)")

create_config_response = evaluation_client.create_online_evaluation_config(
    onlineEvaluationConfigName=EVAL_CONFIG_NAME,
    description=EVAL_DESCRIPTION,
    rule={
        "samplingConfig": {"samplingPercentage": SAMPLING_PERCENTAGE},
        "sessionConfig": {"sessionTimeoutMinutes": SESSION_TIMEOUT_MINUTES},
    },
    dataSourceConfig={
        "cloudWatchLogs": {
            "logGroupNames": [LOG_GROUP_NAME],
            "serviceNames": [SERVICE_NAME],
        }
    },
    evaluators=all_evaluators,
    evaluationExecutionRoleArn=EVALUATION_ROLE_ARN,
    enableOnCreate=True,
)

config_id = create_config_response["onlineEvaluationConfigId"]
config_details = evaluation_client.get_online_evaluation_config(onlineEvaluationConfigId=config_id)

print(f"\n✓ Created config: {config_id}")
print(f"Status: {config_details['status']}")
# Out:
# Total evaluators: 10 (13 builtin + 1 custom)
#
# ✓ Created config: web_search_agent_online_eval-Kelx5TGHO1
# Status: ACTIVE

# %% [markdown]
# ## 4. AgentCore Runtime 클라이언트

# %%
agentcore_client = boto3.client("bedrock-agentcore", region_name=AWS_REGION)


def invoke_agentcore(user_message, session_id=None):
    """
    세션을 관리하면서 에이전트를 호출합니다.

    인수:
        user_message: 에이전트에 보낼 프롬프트
        session_id: 대화 컨텍스트를 유지하기 위한 선택적 세션 ID

    반환값:
        에이전트의 응답 텍스트
    """
    # 요청 parameter를 구성합니다.
    request_params = {
        "agentRuntimeArn": AGENT_ARN,
        "qualifier": QUALIFIER,
        "payload": json.dumps({"prompt": user_message}),
    }

    # session_id가 제공된 경우 추가합니다.
    if session_id is not None:
        request_params["runtimeSessionId"] = session_id

    boto3_response = agentcore_client.invoke_agent_runtime(**request_params)

    content = []
    if "text/event-stream" in boto3_response.get("contentType", ""):
        for line in boto3_response["response"].iter_lines(chunk_size=1):
            if line:
                line = line.decode("utf-8")
                if line.startswith("data: "):
                    line = line[6:]
                    content.append(line)
    else:
        events = []
        for event in boto3_response.get("response", []):
            events.append(event)
        if events:
            content.append(json.loads(events[0].decode("utf-8")))

    return "\n".join(str(c) for c in content)

# %% [markdown]
# ## 5. 테스트 사례 생성

# %%
generator = DatasetGenerator[str, str](str, str)

task_description = f"""
Task: {AGENT_CAPABILITIES}
Limitations: {AGENT_LIMITATIONS}
Available tools: {", ".join(AGENT_TOOLS)}
Complexity: {AGENT_COMPLEXITY}
"""

dataset = await generator.from_scratch_async(
    topics=AGENT_TOPICS, task_description=task_description, num_cases=NUM_TEST_CASES
)

print(f"Generated {len(dataset.cases)} test cases")
# Out:
# Generated 10 test cases

# %% [markdown]
# ## 6. 테스트 사례 미리 보기

# %%
for i, case in enumerate(dataset.cases, 1):
    print(f"\nCase {i}: {case.input}")
    print(f"Expected: {case.expected_output}")
# Out:
# Case 1: What are the main tourist attractions and must-see places in San Francisco?
# Expected: List of major San Francisco attractions (Golden Gate Bridge, Alcatraz, Fisherman's Wharf, etc.), brief descriptions, locations, operating hours, and official tourism website information.
#
# Case 2: How tall is the Statue of Liberty and what are the current visiting requirements?
# Expected: Height of Statue of Liberty (151 feet/46 meters statue, 305 feet/93 meters including pedestal), current visiting procedures including advance reservations, security requirements, ferry information, and any COVID-related restrictions or changes to normal operations.
#
# Case 3: What were the most significant moments or record-breaking performances from the most recent Summer Olympics? I'm looking for both athletic achievements and any notable stories that made headlines.
# Expected: The AI should search for highlights, records, and notable stories from the most recent Summer Olympics, providing specific athletic achievements, record times/scores, athlete names, and significant moments that received media coverage. Should include both performance statistics and human interest stories from sports news sources.
#
# Case 4: Which areas of Yellowstone and Glacier National Parks are currently accessible, and what seasonal closures or restrictions are in effect? I'm planning a road trip and need to know about road conditions and facility availability.
# Expected: Current park accessibility status, road closures, facility operations, seasonal restrictions, and recommendations for route planning with official National Park Service information and recent visitor reports.
#
# Case 5: How tall is the Eiffel Tower and when was it built?
# Expected: Basic factual information about the Eiffel Tower including its height (324 meters/1,063 feet), construction dates (1887-1889), and key historical details. Should include verified information from official sources or reputable encyclopedic websites.
#
# Case 6: What are the current travel conditions and safety considerations for visiting national parks in Utah (Zion, Arches, Bryce Canyon) during this time of year? Include information about road conditions, park alerts, and recommended preparations.
# Expected: The AI should search for current conditions at Utah national parks. Expected output should include: 1) Current road conditions and accessibility for each park 2) Active park alerts or warnings 3) Seasonal considerations for current time of year 4) Weather-related impacts on park access 5) Recommended gear and preparations 6) Park service announcements or temporary closures 7) Source URLs from National Park Service or official park websites. Information should focus on practical travel planning and safety considerations.
#
# Case 7: What are the current COVID-related travel restrictions for US citizens traveling to European Union countries? Are there any health requirements or documentation needed for entry?
# Expected: Current COVID-related travel requirements for US citizens entering EU countries, including vaccination requirements, testing protocols, health documentation needed, and any quarantine measures. Information should be up-to-date and include sources from official government websites, US State Department, and EU health authorities.
#
# Case 8: What are the current trends in sustainable tourism and eco-friendly travel options that have emerged in 2024?
# Expected: Overview of 2024 sustainable tourism trends including new eco-friendly travel options, green certification programs, sustainable accommodation trends, responsible travel practices, and examples of destinations or companies leading these initiatives with source references from travel industry publications.
#
# Case 9: I heard about a new archaeological discovery that's been in the news recently involving ancient civilizations. Can you find current information about significant archaeological finds from this year, what they've revealed, and why they're considered important?
# Expected: The AI should search for recent archaeological discoveries from the current year, provide details about the findings, explain their historical significance, include information about the research teams involved, and present the discoveries in context of what they reveal about ancient civilizations. Should include credible news sources.
#
# Case 10: I'm preparing for a trivia competition and need current information on diverse topics. Can you search for: 1) Recent scientific discoveries or breakthroughs in 2024 that might appear in trivia, 2) Current world records that have been set or broken this year, 3) Recent changes in country names, currencies, or political leadership that are notable, and 4) Pop culture phenomena, viral trends, or award winners from 2024 that have staying power?
# Expected: The response should provide: Comprehensive list of 2024 scientific breakthroughs with significance and potential trivia relevance, current world records with dates and details of record-breaking achievements, recent geopolitical changes including leadership transitions and policy shifts, analysis of 2024 pop culture trends and award winners with cultural impact assessment, all organized by category with verification from multiple current sources and URLs.

# %% [markdown]
# ## 7. 작업 함수 정의

# %%
def task_function(case: Case) -> str:
    # 이 테스트 사례를 위한 새 세션을 생성합니다.
    session_id = str(uuid.uuid4())
    print(f"\n🆕 Started new session: {session_id}")

    user_sim = ActorSimulator.from_case_for_user_simulator(case=case, max_turns=MAX_TURNS)

    user_message = case.input
    final_response = ""

    print(f"\n{'=' * 80}")
    print(f"Test Case: {case.input}")
    print(f"Expected: {case.expected_output}")
    print(f"{'=' * 80}")

    turn = 1
    while user_sim.has_next():
        print(f"\nTurn {turn}: {user_message}")
        agent_response = invoke_agentcore(user_message, session_id=session_id)
        final_response = agent_response
        print(f"Agent: {agent_response[:200]}...")

        user_result = user_sim.act(agent_response)
        user_message = str(user_result.structured_output.message)
        turn += 1

    print(f"🔚 Ended session: {session_id}")

    return final_response

# %% [markdown]
# ## 8. 평가 실행

# %%
results = []

for i, case in enumerate(dataset.cases, 1):
    print(f"\n\n{'#' * 80}")
    print(f"# Running Test Case {i}/{len(dataset.cases)}")
    print(f"{'#' * 80}")

    try:
        response = task_function(case)
        results.append(
            {
                "case_number": i,
                "input": case.input,
                "expected": case.expected_output,
                "actual": response,
                "status": "success",
            }
        )
    except Exception as e:
        print(f"ERROR: {e}")
        results.append(
            {
                "case_number": i,
                "input": case.input,
                "expected": case.expected_output,
                "actual": str(e),
                "status": "error",
            }
        )

print(f"\n\nCompleted {len(results)} test cases")
print(f"Successful: {sum(1 for r in results if r['status'] == 'success')}")
print(f"Errors: {sum(1 for r in results if r['status'] == 'error')}")
# Out:
# ################################################################################
# # Running Test Case 1/10
# ################################################################################
#
# 🆕 Started new session: da90c0d6-85b8-44fd-b90a-65d34093b242
#
# ================================================================================
# Test Case: What are the main tourist attractions and must-see places in San Francisco?
# Expected: List of major San Francisco attractions (Golden Gate Bridge, Alcatraz, Fisherman's Wharf, etc.), brief descriptions, locations, operating hours, and official tourism website information.
# ================================================================================
#
# Turn 1: What are the main tourist attractions and must-see places in San Francisco?
# ERROR: Unterminated string starting at: line 1 column 1 (char 0)
#
#
# ################################################################################
# # Running Test Case 2/10
# ################################################################################
#
# 🆕 Started new session: f93faa67-79ce-4dad-bbd4-b901e9add58a
#
# ================================================================================
# Test Case: How tall is the Statue of Liberty and what are the current visiting requirements?
# Expected: Height of Statue of Liberty (151 feet/46 meters statue, 305 feet/93 meters including pedestal), current visiting procedures including advance reservations, security requirements, ferry information, and any COVID-related restrictions or changes to normal operations.
# ================================================================================
#
# Turn 1: How tall is the Statue of Liberty and what are the current visiting requirements?
# ERROR: Unterminated string starting at: line 1 column 1 (char 0)
#
#
# ################################################################################
# # Running Test Case 3/10
# ################################################################################
#
# 🆕 Started new session: 3647d55c-0041-4560-9df4-a1ab35ee66ee
#
# ================================================================================
# Test Case: What were the most significant moments or record-breaking performances from the most recent Summer Olympics? I'm looking for both athletic achievements and any notable stories that made headlines.
# Expected: The AI should search for highlights, records, and notable stories from the most recent Summer Olympics, providing specific athletic achievements, record times/scores, athlete names, and significant moments that received media coverage. Should include both performance statistics and human interest stories from sports news sources.
# ================================================================================
#
# Turn 1: What were the most significant moments or record-breaking performances from the most recent Summer Olympics? I'm looking for both athletic achievements and any notable stories that made headlines.
# ERROR: Unterminated string starting at: line 1 column 1 (char 0)
#
#
# ################################################################################
# # Running Test Case 4/10
# ################################################################################
#
# 🆕 Started new session: 21e91713-f225-49c9-b9ca-1a9b3bb16e9e
#
# ================================================================================
# Test Case: Which areas of Yellowstone and Glacier National Parks are currently accessible, and what seasonal closures or restrictions are in effect? I'm planning a road trip and need to know about road conditions and facility availability.
# Expected: Current park accessibility status, road closures, facility operations, seasonal restrictions, and recommendations for route planning with official National Park Service information and recent visitor reports.
# ================================================================================
#
# Turn 1: Which areas of Yellowstone and Glacier National Parks are currently accessible, and what seasonal closures or restrictions are in effect? I'm planning a road trip and need to know about road conditions and facility availability.
# ERROR: Read timeout on endpoint URL: "https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A484907519812%3Aruntime%2Flanggraph_web_search_agent-NgiYXW2dze/invocations?qualifier=DEFAULT"
#
#
# ################################################################################
# # Running Test Case 5/10
# ################################################################################
#
# 🆕 Started new session: a5a2446b-2068-4552-9f55-54660cca8ab7
#
# ================================================================================
# Test Case: How tall is the Eiffel Tower and when was it built?
# Expected: Basic factual information about the Eiffel Tower including its height (324 meters/1,063 feet), construction dates (1887-1889), and key historical details. Should include verified information from official sources or reputable encyclopedic websites.
# ================================================================================
#
# Turn 1: How tall is the Eiffel Tower and when was it built?
# Agent: Based on the search results, I can provide you with information about the Eiffel Tower:
#
# Height:
# - The Eiffel Tower is 324 meters (1,063 ft) tall
# - This makes it about the same height as an 81-story b...
# 🔚 Ended session: a5a2446b-2068-4552-9f55-54660cca8ab7
#
#
# ################################################################################
# # Running Test Case 6/10
# ################################################################################
#
# 🆕 Started new session: ae5f695e-4fb8-440b-9bc3-8895a2363b63
#
# ================================================================================
# Test Case: What are the current travel conditions and safety considerations for visiting national parks in Utah (Zion, Arches, Bryce Canyon) during this time of year? Include information about road conditions, park alerts, and recommended preparations.
# Expected: The AI should search for current conditions at Utah national parks. Expected output should include: 1) Current road conditions and accessibility for each park 2) Active park alerts or warnings 3) Seasonal considerations for current time of year 4) Weather-related impacts on park access 5) Recommended gear and preparations 6) Park service announcements or temporary closures 7) Source URLs from National Park Service or official park websites. Information should focus on practical travel planning and safety considerations.
# ================================================================================
#
# Turn 1: What are the current travel conditions and safety considerations for visiting national parks in Utah (Zion, Arches, Bryce Canyon) during this time of year? Include information about road conditions, park alerts, and recommended preparations.
# ERROR: Read timeout on endpoint URL: "https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A484907519812%3Aruntime%2Flanggraph_web_search_agent-NgiYXW2dze/invocations?qualifier=DEFAULT"
#
#
# ################################################################################
# # Running Test Case 7/10
# ################################################################################
#
# 🆕 Started new session: 0ad08d4f-f394-4791-a872-f58febd7bcc8
#
# ================================================================================
# Test Case: What are the current COVID-related travel restrictions for US citizens traveling to European Union countries? Are there any health requirements or documentation needed for entry?
# Expected: Current COVID-related travel requirements for US citizens entering EU countries, including vaccination requirements, testing protocols, health documentation needed, and any quarantine measures. Information should be up-to-date and include sources from official government websites, US State Department, and EU health authorities.
# ================================================================================
#
# Turn 1: What are the current COVID-related travel restrictions for US citizens traveling to European Union countries? Are there any health requirements or documentation needed for entry?
# ERROR: Unterminated string starting at: line 1 column 1 (char 0)
#
#
# ################################################################################
# # Running Test Case 8/10
# ################################################################################
#
# 🆕 Started new session: 8ffbf85d-659f-43a2-9b16-984cc9adccbe
#
# ================================================================================
# Test Case: What are the current trends in sustainable tourism and eco-friendly travel options that have emerged in 2024?
# Expected: Overview of 2024 sustainable tourism trends including new eco-friendly travel options, green certification programs, sustainable accommodation trends, responsible travel practices, and examples of destinations or companies leading these initiatives with source references from travel industry publications.
# ================================================================================
#
# Turn 1: What are the current trends in sustainable tourism and eco-friendly travel options that have emerged in 2024?
# ERROR: Unterminated string starting at: line 1 column 1 (char 0)
#
#
# ################################################################################
# # Running Test Case 9/10
# ################################################################################
#
# 🆕 Started new session: 15d5fc35-40ac-4da9-a814-b658b0954e95
#
# ================================================================================
# Test Case: I heard about a new archaeological discovery that's been in the news recently involving ancient civilizations. Can you find current information about significant archaeological finds from this year, what they've revealed, and why they're considered important?
# Expected: The AI should search for recent archaeological discoveries from the current year, provide details about the findings, explain their historical significance, include information about the research teams involved, and present the discoveries in context of what they reveal about ancient civilizations. Should include credible news sources.
# ================================================================================
#
# Turn 1: I heard about a new archaeological discovery that's been in the news recently involving ancient civilizations. Can you find current information about significant archaeological finds from this year, what they've revealed, and why they're considered important?
# ERROR: Read timeout on endpoint URL: "https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A484907519812%3Aruntime%2Flanggraph_web_search_agent-NgiYXW2dze/invocations?qualifier=DEFAULT"
#
#
# ################################################################################
# # Running Test Case 10/10
# ################################################################################
#
# 🆕 Started new session: a8359cfb-1082-4299-b330-57c824ed4fdc
#
# ================================================================================
# Test Case: I'm preparing for a trivia competition and need current information on diverse topics. Can you search for: 1) Recent scientific discoveries or breakthroughs in 2024 that might appear in trivia, 2) Current world records that have been set or broken this year, 3) Recent changes in country names, currencies, or political leadership that are notable, and 4) Pop culture phenomena, viral trends, or award winners from 2024 that have staying power?
# Expected: The response should provide: Comprehensive list of 2024 scientific breakthroughs with significance and potential trivia relevance, current world records with dates and details of record-breaking achievements, recent geopolitical changes including leadership transitions and policy shifts, analysis of 2024 pop culture trends and award winners with cultural impact assessment, all organized by category with verification from multiple current sources and URLs.
# ================================================================================
#
# Turn 1: I'm preparing for a trivia competition and need current information on diverse topics. Can you search for: 1) Recent scientific discoveries or breakthroughs in 2024 that might appear in trivia, 2) Current world records that have been set or broken this year, 3) Recent changes in country names, currencies, or political leadership that are notable, and 4) Pop culture phenomena, viral trends, or award winners from 2024 that have staying power?
# ERROR: Read timeout on endpoint URL: "https://bedrock-agentcore.us-east-1.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-east-1%3A484907519812%3Aruntime%2Flanggraph_web_search_agent-NgiYXW2dze/invocations?qualifier=DEFAULT"
#
#
# Completed 10 test cases
# Successful: 1
# Errors: 9

# %% [markdown]
# ## 9. 결과 확인

# %%
import pandas as pd

df = pd.DataFrame(results)
df
# Out:
#    case_number                                              input  \
# 0            1  What are the main tourist attractions and must...
# 1            2  How tall is the Statue of Liberty and what are...
# 2            3  What were the most significant moments or reco...
# 3            4  Which areas of Yellowstone and Glacier Nationa...
# 4            5  How tall is the Eiffel Tower and when was it b...
# 5            6  What are the current travel conditions and saf...
# 6            7  What are the current COVID-related travel rest...
# 7            8  What are the current trends in sustainable tou...
# 8            9  I heard about a new archaeological discovery t...
# 9           10  I'm preparing for a trivia competition and nee...
#
#                                             expected  \
# 0  List of major San Francisco attractions (Golde...
# 1  Height of Statue of Liberty (151 feet/46 meter...
# 2  The AI should search for highlights, records, ...
# 3  Current park accessibility status, road closur...
# 4  Basic factual information about the Eiffel Tow...
# 5  The AI should search for current conditions at...
# 6  Current COVID-related travel requirements for ...
# 7  Overview of 2024 sustainable tourism trends in...
# 8  The AI should search for recent archaeological...
# 9  The response should provide: Comprehensive lis...
#
#                                               actual   status
# 0  Unterminated string starting at: line 1 column...    error
# 1  Unterminated string starting at: line 1 column...    error
# 2  Unterminated string starting at: line 1 column...    error
# 3  Read timeout on endpoint URL: "https://bedrock...    error
# 4  Based on the search results, I can provide you...  success
# 5  Read timeout on endpoint URL: "https://bedrock...    error
# 6  Unterminated string starting at: line 1 column...    error
# 7  Unterminated string starting at: line 1 column...    error
# 8  Read timeout on endpoint URL: "https://bedrock...    error
# 9  Read timeout on endpoint URL: "https://bedrock...    error

# %% [markdown]
# ## 요약
#
# 이번 평가에서는 다음 evaluator로 웹 검색 에이전트를 테스트했습니다.
#
# **총 14개 evaluator:**
# - 기본 제공 evaluator 13개(Correctness, Faithfulness, Helpfulness, Relevance, Conciseness, Coherence, InstructionFollowing, Refusal, Harmfulness, Stereotyping, GoalSuccessRate, ToolSelectionAccuracy, ToolParameterAccuracy)
# - 사용자 지정 LLM-as-a-Judge evaluator 1개(Web Search Quality)
#
# 모든 trace와 평가는 CloudWatch에 캡처되며 AgentCore 대시보드에서 확인할 수 있습니다.
#
# # 마무리
